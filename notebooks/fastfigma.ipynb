# %%
from dotenv import load_dotenv
import os
import json
from fastFigma.project import FigmaProject
load_dotenv()
# Out:
# True

# %%
FIGMA_API_TOKEN = os.getenv("FIGMA_API_TOKEN")
URL = "https://www.figma.com/design/4zPVSizRrtpANhJoTejFYu/fastFigma?t=9rwh0m4vsoX3GeMw-1"

project = FigmaProject(url=URL, api_token=FIGMA_API_TOKEN)
ui_elements = project.ui_elements

print(json.dumps(ui_elements, indent=2))
# Out:
# [
#   {
#     "id": "1:2",
#     "name": "$ui-temperature-widget",
#     "type": "FRAME",
#     "scrollBehavior": "SCROLLS",
#     "children": [
#       {
#         "id": "1:5",
#         "name": "top",
#         "type": "FRAME",
#         "scrollBehavior": "SCROLLS",
#         "children": [
#           {
#             "id": "1:8",
#             "name": "Temperature",
#             "type": "TEXT",
#             "scrollBehavior": "SCROLLS",
#             "blendMode": "PASS_THROUGH",
#             "fills": [
#               {
#                 "blendMode": "NORMAL",
#                 "type": "SOLID",
#                 "color": {
#                   "r": 1.0,
#                   "g": 1.0,
#                   "b": 1.0,
#                   "a": 1.0
#                 }
#               }
#             ],
#             "strokes": [],
#             "strokeWeight": 1.0,
#             "strokeAlign": "OUTSIDE",
#             "absoluteBoundingBox": {
#               "x": -464.0,
#               "y": -570.0,
#               "width": 211.0,
#               "height": 44.0
#             },
#             "absoluteRenderBounds": {
#               "x": -463.359375,
#               "y": -558.84375,
#               "width": 208.265625,
#               "height": 30.53125
#             },
#             "constraints": {
#               "vertical": "TOP",
#               "horizontal": "LEFT"
#             },
#             "layoutAlign": "INHERIT",
#             "layoutGrow": 0.0,
#             "layoutSizingHorizontal": "HUG",
#             "layoutSizingVertical": "HUG",
#             "characters": "Temperature",
#             "characterStyleOverrides": [],
#             "styleOverrideTable": {},
#             "lineTypes": [
#               "NONE"
#             ],
#             "lineIndentations": [
#               0
#             ],
#             "style": {
#               "fontFamily": "Open Sans",
#               "fontPostScriptName": "OpenSans-Bold",
#               "fontStyle": "Bold",
#               "fontWeight": 700,
#               "textAutoResize": "WIDTH_AND_HEIGHT",
#               "fontSize": 32.0,
#               "textAlignHorizontal": "LEFT",
#               "textAlignVertical": "TOP",
#               "letterSpacing": 0.0,
#               "lineHeightPx": 43.578125,
#               "lineHeightPercent": 100.0,
#               "lineHeightUnit": "INTRINSIC_%"
#             },
#             "layoutVersion": 4,
#             "effects": [],
#             "interactions": []
#           }
#         ],
#         "blendMode": "PASS_THROUGH",
#         "clipsContent": true,
#         "background": [
#           {
#             "blendMode": "NORMAL",
#             "type": "SOLID",
#             "color": {
#               "r": 0.09019608050584793,
#               "g": 0.32156863808631897,
#               "b": 0.9333333373069763,
#               "a": 1.0
#             }
#           }
#         ],
#         "fills": [
#           {
#             "blendMode": "NORMAL",
#             "type": "SOLID",
#             "color": {
#               "r": 0.09019608050584793,
#               "g": 0.32156863808631897,
#               "b": 0.9333333373069763,
#               "a": 1.0
#             }
#           }
#         ],
#         "strokes": [],
#         "cornerRadius": 24.0,
#         "cornerSmoothing": 0.0,
#         "strokeWeight": 1.0,
#         "strokeAlign": "INSIDE",
#         "backgroundColor": {
#           "r": 0.09019608050584793,
#           "g": 0.32156863808631897,
#           "b": 0.9333333373069763,
#           "a": 1.0
#         },
#         "layoutMode": "HORIZONTAL",
#         "itemSpacing": 10.0,
#         "primaryAxisSizingMode": "FIXED",
#         "counterAxisAlignItems": "MAX",
#         "paddingLeft": 24.0,
#         "paddingRight": 24.0,
#         "paddingTop": 24.0,
#         "paddingBottom": 24.0,
#         "layoutWrap": "NO_WRAP",
#         "absoluteBoundingBox": {
#           "x": -488.0,
#           "y": -594.0,
#           "width": 584.0,
#           "height": 92.0
#         },
#         "absoluteRenderBounds": {
#           "x": -492.0,
#           "y": -594.0,
#           "width": 592.0,
#           "height": 100.0
#         },
#         "constraints": {
#           "vertical": "TOP",
#           "horizontal": "LEFT"
#         },
#         "layoutAlign": "STRETCH",
#         "layoutGrow": 0.0,
#         "layoutSizingHorizontal": "FILL",
#         "layoutSizingVertical": "HUG",
#         "effects": [
#           {
#             "type": "DROP_SHADOW",
#             "visible": true,
#             "color": {
#               "r": 0.0,
#               "g": 0.0,
#               "b": 0.0,
#               "a": 0.25
#             },
#             "blendMode": "NORMAL",
#             "offset": {
#               "x": 0.0,
#               "y": 4.0
#             },
#             "radius": 4.0,
#             "showShadowBehindNode": false
#           }
#         ],
#         "interactions": []
#       },
#       {
#         "id": "1:6",
#         "name": "bottom",
#         "type": "FRAME",
#         "scrollBehavior": "SCROLLS",
#         "children": [
#           {
#             "id": "1:15",
#             "name": "Image Div",
#             "type": "FRAME",
#             "scrollBehavior": "SCROLLS",
#             "children": [
#               {
#                 "id": "1:17",
#                 "name": "Sun",
#                 "type": "VECTOR",
#                 "scrollBehavior": "SCROLLS",
#                 "blendMode": "PASS_THROUGH",
#                 "fills": [
#                   {
#                     "blendMode": "NORMAL",
#                     "type": "SOLID",
#                     "color": {
#                       "r": 0.9647058844566345,
#                       "g": 0.7647058963775635,
#                       "b": 0.0941176488995552,
#                       "a": 1.0
#                     }
#                   }
#                 ],
#                 "strokes": [],
#                 "strokeWeight": 1.0,
#                 "strokeAlign": "INSIDE",
#                 "absoluteBoundingBox": {
#                   "x": -468.0,
#                   "y": -402.0,
#                   "width": 180.0,
#                   "height": 180.0
#                 },
#                 "absoluteRenderBounds": {
#                   "x": -468.0,
#                   "y": -402.0,
#                   "width": 180.0,
#                   "height": 180.0
#                 },
#                 "targetAspectRatio": {
#                   "x": 22.0,
#                   "y": 22.0
#                 },
#                 "constraints": {
#                   "vertical": "TOP",
#                   "horizontal": "LEFT"
#                 },
#                 "layoutAlign": "INHERIT",
#                 "layoutGrow": 1.0,
#                 "layoutSizingHorizontal": "FIXED",
#                 "layoutSizingVertical": "FILL",
#                 "effects": [],
#                 "interactions": []
#               }
#             ],
#             "blendMode": "PASS_THROUGH",
#             "clipsContent": true,
#             "background": [],
#             "fills": [],
#             "strokes": [],
#             "strokeWeight": 1.0,
#             "strokeAlign": "INSIDE",
#             "backgroundColor": {
#               "r": 0.0,
#               "g": 0.0,
#               "b": 0.0,
#               "a": 0.0
#             },
#             "layoutMode": "VERTICAL",
#             "counterAxisSizingMode": "FIXED",
#             "itemSpacing": 10.0,
#             "primaryAxisSizingMode": "FIXED",
#             "counterAxisAlignItems": "CENTER",
#             "primaryAxisAlignItems": "CENTER",
#             "paddingLeft": 10.0,
#             "paddingRight": 10.0,
#             "paddingTop": 10.0,
#             "paddingBottom": 10.0,
#             "layoutWrap": "NO_WRAP",
#             "absoluteBoundingBox": {
#               "x": -478.0,
#               "y": -412.0,
#               "width": 200.0,
#               "height": 200.0
#             },
#             "absoluteRenderBounds": {
#               "x": -478.0,
#               "y": -412.0,
#               "width": 200.0,
#               "height": 200.0
#             },
#             "constraints": {
#               "vertical": "TOP",
#               "horizontal": "LEFT"
#             },
#             "layoutAlign": "INHERIT",
#             "layoutGrow": 0.0,
#             "layoutSizingHorizontal": "FIXED",
#             "layoutSizingVertical": "FIXED",
#             "effects": [],
#             "interactions": []
#           },
#           {
#             "id": "1:10",
#             "name": "$mqtt:127.0.0.0.1:8000:temperature/sensor/#",
#             "type": "TEXT",
#             "scrollBehavior": "SCROLLS",
#             "blendMode": "PASS_THROUGH",
#             "fills": [
#               {
#                 "blendMode": "NORMAL",
#                 "type": "SOLID",
#                 "color": {
#                   "r": 0.21960784494876862,
#                   "g": 0.21960784494876862,
#                   "b": 0.250980406999588,
#                   "a": 1.0
#                 }
#               }
#             ],
#             "strokes": [],
#             "strokeWeight": 1.0,
#             "strokeAlign": "OUTSIDE",
#             "absoluteBoundingBox": {
#               "x": -238.0,
#               "y": -399.0,
#               "width": 147.0,
#               "height": 174.0
#             },
#             "absoluteRenderBounds": {
#               "x": -237.125,
#               "y": -354.6875,
#               "width": 145.375,
#               "height": 100.6875
#             },
#             "constraints": {
#               "vertical": "TOP",
#               "horizontal": "LEFT"
#             },
#             "layoutAlign": "INHERIT",
#             "layoutGrow": 0.0,
#             "layoutSizingHorizontal": "HUG",
#             "layoutSizingVertical": "HUG",
#             "characters": "22",
#             "characterStyleOverrides": [],
#             "styleOverrideTable": {},
#             "lineTypes": [
#               "NONE"
#             ],
#             "lineIndentations": [
#               0
#             ],
#             "style": {
#               "fontFamily": "Open Sans",
#               "fontPostScriptName": "OpenSans-Bold",
#               "fontStyle": "Bold",
#               "fontWeight": 700,
#               "textAutoResize": "WIDTH_AND_HEIGHT",
#               "fontSize": 128.0,
#               "textAlignHorizontal": "LEFT",
#               "textAlignVertical": "TOP",
#               "letterSpacing": 0.0,
#               "lineHeightPx": 174.3125,
#               "lineHeightPercent": 100.0,
#               "lineHeightUnit": "INTRINSIC_%"
#             },
#             "layoutVersion": 4,
#             "effects": [
#               {
#                 "type": "DROP_SHADOW",
#                 "visible": true,
#                 "color": {
#                   "r": 0.0,
#                   "g": 0.0,
#                   "b": 0.0,
#                   "a": 0.25
#                 },
#                 "blendMode": "NORMAL",
#                 "offset": {
#                   "x": 0.0,
#                   "y": 4.0
#                 },
#                 "radius": 4.0,
#                 "showShadowBehindNode": false
#               }
#             ],
#             "interactions": []
#           },
#           {
#             "id": "1:11",
#             "name": "\u00b0C",
#             "type": "TEXT",
#             "scrollBehavior": "SCROLLS",
#             "blendMode": "PASS_THROUGH",
#             "fills": [
#               {
#                 "blendMode": "NORMAL",
#                 "type": "SOLID",
#                 "color": {
#                   "r": 0.21960784494876862,
#                   "g": 0.21960784494876862,
#                   "b": 0.250980406999588,
#                   "a": 1.0
#                 }
#               }
#             ],
#             "strokes": [],
#             "strokeWeight": 1.0,
#             "strokeAlign": "OUTSIDE",
#             "absoluteBoundingBox": {
#               "x": -51.0,
#               "y": -399.0,
#               "width": 137.0,
#               "height": 174.0
#             },
#             "absoluteRenderBounds": {
#               "x": -46.0,
#               "y": -354.6875,
#               "width": 126.9375,
#               "height": 93.9375
#             },
#             "constraints": {
#               "vertical": "TOP",
#               "horizontal": "LEFT"
#             },
#             "layoutAlign": "INHERIT",
#             "layoutGrow": 0.0,
#             "layoutSizingHorizontal": "HUG",
#             "layoutSizingVertical": "HUG",
#             "characters": "\u00b0C",
#             "characterStyleOverrides": [],
#             "styleOverrideTable": {},
#             "lineTypes": [
#               "NONE"
#             ],
#             "lineIndentations": [
#               0
#             ],
#             "style": {
#               "fontFamily": "Open Sans",
#               "fontPostScriptName": "OpenSans-Bold",
#               "fontStyle": "Bold",
#               "fontWeight": 700,
#               "textAutoResize": "WIDTH_AND_HEIGHT",
#               "fontSize": 128.0,
#               "textAlignHorizontal": "LEFT",
#               "textAlignVertical": "TOP",
#               "letterSpacing": 0.0,
#               "lineHeightPx": 174.3125,
#               "lineHeightPercent": 100.0,
#               "lineHeightUnit": "INTRINSIC_%"
#             },
#             "layoutVersion": 4,
#             "effects": [],
#             "interactions": []
#           }
#         ],
#         "blendMode": "PASS_THROUGH",
#         "clipsContent": true,
#         "background": [],
#         "fills": [],
#         "strokes": [],
#         "strokeWeight": 1.0,
#         "strokeAlign": "INSIDE",
#         "backgroundColor": {
#           "r": 0.0,
#           "g": 0.0,
#           "b": 0.0,
#           "a": 0.0
#         },
#         "layoutMode": "HORIZONTAL",
#         "itemSpacing": 40.0,
#         "counterAxisAlignItems": "CENTER",
#         "paddingLeft": 10.0,
#         "paddingRight": 10.0,
#         "paddingTop": 10.0,
#         "paddingBottom": 10.0,
#         "layoutWrap": "NO_WRAP",
#         "absoluteBoundingBox": {
#           "x": -488.0,
#           "y": -422.0,
#           "width": 584.0,
#           "height": 220.0
#         },
#         "absoluteRenderBounds": {
#           "x": -488.0,
#           "y": -422.0,
#           "width": 584.0,
#           "height": 220.0
#         },
#         "constraints": {
#           "vertical": "TOP",
#           "horizontal": "LEFT"
#         },
#         "layoutAlign": "INHERIT",
#         "layoutGrow": 0.0,
#         "layoutSizingHorizontal": "HUG",
#         "layoutSizingVertical": "HUG",
#         "effects": [],
#         "interactions": []
#       }
#     ],
#     "blendMode": "PASS_THROUGH",
#     "clipsContent": true,
#     "background": [
#       {
#         "blendMode": "NORMAL",
#         "type": "SOLID",
#         "color": {
#           "r": 1.0,
#           "g": 1.0,
#           "b": 1.0,
#           "a": 1.0
#         }
#       }
#     ],
#     "fills": [
#       {
#         "blendMode": "NORMAL",
#         "type": "SOLID",
#         "color": {
#           "r": 1.0,
#           "g": 1.0,
#           "b": 1.0,
#           "a": 1.0
#         }
#       }
#     ],
#     "strokes": [
#       {
#         "blendMode": "NORMAL",
#         "type": "SOLID",
#         "color": {
#           "r": 0.942307710647583,
#           "g": 0.942307710647583,
#           "b": 0.942307710647583,
#           "a": 1.0
#         }
#       }
#     ],
#     "cornerRadius": 80.0,
#     "cornerSmoothing": 0.0,
#     "strokeWeight": 1.0,
#     "strokeAlign": "INSIDE",
#     "backgroundColor": {
#       "r": 1.0,
#       "g": 1.0,
#       "b": 1.0,
#       "a": 1.0
#     },
#     "layoutMode": "VERTICAL",
#     "itemSpacing": 80.0,
#     "counterAxisAlignItems": "CENTER",
#     "primaryAxisAlignItems": "CENTER",
#     "paddingLeft": 80.0,
#     "paddingRight": 80.0,
#     "paddingTop": 80.0,
#     "paddingBottom": 80.0,
#     "layoutWrap": "NO_WRAP",
#     "absoluteBoundingBox": {
#       "x": -568.0,
#       "y": -674.0,
#       "width": 744.0,
#       "height": 552.0
#     },
#     "absoluteRenderBounds": {
#       "x": -572.0,
#       "y": -674.0,
#       "width": 752.0,
#       "height": 560.0
#     },
#     "constraints": {
#       "vertical": "TOP",
#       "horizontal": "LEFT"
#     },
#     "layoutSizingHorizontal": "HUG",
#     "layoutSizingVertical": "HUG",
#     "effects": [
#       {
#         "type": "DROP_SHADOW",
#         "visible": true,
#         "color": {
#           "r": 0.0,
#           "g": 0.0,
#           "b": 0.0,
#           "a": 0.25
#         },
#         "blendMode": "NORMAL",
#         "offset": {
#           "x": 0.0,
#           "y": 4.0
#         },
#         "radius": 4.0,
#         "showShadowBehindNode": false
#       }
#     ],
#     "interactions": []
#   },
#   {
#     "id": "31:21",
#     "name": "$ui-temperature-widget-small",
#     "type": "FRAME",
#     "scrollBehavior": "SCROLLS",
#     "children": [
#       {
#         "id": "31:22",
#         "name": "top",
#         "type": "FRAME",
#         "scrollBehavior": "SCROLLS",
#         "children": [
#           {
#             "id": "31:23",
#             "name": "Temperature",
#             "type": "TEXT",
#             "scrollBehavior": "SCROLLS",
#             "blendMode": "PASS_THROUGH",
#             "fills": [
#               {
#                 "blendMode": "NORMAL",
#                 "type": "SOLID",
#                 "color": {
#                   "r": 1.0,
#                   "g": 1.0,
#                   "b": 1.0,
#                   "a": 1.0
#                 }
#               }
#             ],
#             "strokes": [],
#             "strokeWeight": 1.0,
#             "strokeAlign": "OUTSIDE",
#             "absoluteBoundingBox": {
#               "x": 410.0,
#               "y": -570.0,
#               "width": 211.0,
#               "height": 44.0
#             },
#             "absoluteRenderBounds": {
#               "x": 410.640625,
#               "y": -558.84375,
#               "width": 208.265625,
#               "height": 30.53125
#             },
#             "constraints": {
#               "vertical": "TOP",
#               "horizontal": "LEFT"
#             },
#             "layoutAlign": "INHERIT",
#             "layoutGrow": 0.0,
#             "layoutSizingHorizontal": "HUG",
#             "layoutSizingVertical": "HUG",
#             "characters": "Temperature",
#             "characterStyleOverrides": [],
#             "styleOverrideTable": {},
#             "lineTypes": [
#               "NONE"
#             ],
#             "lineIndentations": [
#               0
#             ],
#             "style": {
#               "fontFamily": "Open Sans",
#               "fontPostScriptName": "OpenSans-Bold",
#               "fontStyle": "Bold",
#               "fontWeight": 700,
#               "textAutoResize": "WIDTH_AND_HEIGHT",
#               "fontSize": 32.0,
#               "textAlignHorizontal": "LEFT",
#               "textAlignVertical": "TOP",
#               "letterSpacing": 0.0,
#               "lineHeightPx": 43.578125,
#               "lineHeightPercent": 100.0,
#               "lineHeightUnit": "INTRINSIC_%"
#             },
#             "layoutVersion": 4,
#             "effects": [],
#             "interactions": []
#           }
#         ],
#         "blendMode": "PASS_THROUGH",
#         "clipsContent": true,
#         "background": [
#           {
#             "blendMode": "NORMAL",
#             "type": "SOLID",
#             "color": {
#               "r": 0.9647058844566345,
#               "g": 0.7647058963775635,
#               "b": 0.0941176488995552,
#               "a": 1.0
#             }
#           }
#         ],
#         "fills": [
#           {
#             "blendMode": "NORMAL",
#             "type": "SOLID",
#             "color": {
#               "r": 0.9647058844566345,
#               "g": 0.7647058963775635,
#               "b": 0.0941176488995552,
#               "a": 1.0
#             }
#           }
#         ],
#         "strokes": [],
#         "cornerRadius": 24.0,
#         "cornerSmoothing": 0.0,
#         "strokeWeight": 1.0,
#         "strokeAlign": "INSIDE",
#         "backgroundColor": {
#           "r": 0.9647058844566345,
#           "g": 0.7647058963775635,
#           "b": 0.0941176488995552,
#           "a": 1.0
#         },
#         "layoutMode": "HORIZONTAL",
#         "itemSpacing": 10.0,
#         "primaryAxisSizingMode": "FIXED",
#         "counterAxisAlignItems": "MAX",
#         "paddingLeft": 24.0,
#         "paddingRight": 24.0,
#         "paddingTop": 24.0,
#         "paddingBottom": 24.0,
#         "layoutWrap": "NO_WRAP",
#         "absoluteBoundingBox": {
#           "x": 386.0,
#           "y": -594.0,
#           "width": 344.0,
#           "height": 92.0
#         },
#         "absoluteRenderBounds": {
#           "x": 382.0,
#           "y": -594.0,
#           "width": 352.0,
#           "height": 100.0
#         },
#         "constraints": {
#           "vertical": "TOP",
#           "horizontal": "LEFT"
#         },
#         "layoutAlign": "STRETCH",
#         "layoutGrow": 0.0,
#         "layoutSizingHorizontal": "FILL",
#         "layoutSizingVertical": "HUG",
#         "effects": [
#           {
#             "type": "DROP_SHADOW",
#             "visible": true,
#             "color": {
#               "r": 0.0,
#               "g": 0.0,
#               "b": 0.0,
#               "a": 0.25
#             },
#             "blendMode": "NORMAL",
#             "offset": {
#               "x": 0.0,
#               "y": 4.0
#             },
#             "radius": 4.0,
#             "showShadowBehindNode": false
#           }
#         ],
#         "interactions": []
#       },
#       {
#         "id": "31:24",
#         "name": "bottom",
#         "type": "FRAME",
#         "scrollBehavior": "SCROLLS",
#         "children": [
#           {
#             "id": "31:26",
#             "name": "$api {\"src\":\"https://api.open-meteo.com/v1/forecast?latitude=60.43&longitude=22.22&current_weather=true\",\"path\":\"current_weather.temperature\",\"trigger\":\"once\"}",
#             "type": "TEXT",
#             "scrollBehavior": "SCROLLS",
#             "blendMode": "PASS_THROUGH",
#             "fills": [
#               {
#                 "blendMode": "NORMAL",
#                 "type": "SOLID",
#                 "color": {
#                   "r": 0.21960784494876862,
#                   "g": 0.21960784494876862,
#                   "b": 0.250980406999588,
#                   "a": 1.0
#                 }
#               }
#             ],
#             "strokes": [],
#             "strokeWeight": 1.0,
#             "strokeAlign": "OUTSIDE",
#             "absoluteBoundingBox": {
#               "x": 396.0,
#               "y": -412.0,
#               "width": 147.0,
#               "height": 174.0
#             },
#             "absoluteRenderBounds": {
#               "x": 396.875,
#               "y": -367.6875,
#               "width": 145.375,
#               "height": 100.6875
#             },
#             "constraints": {
#               "vertical": "TOP",
#               "horizontal": "LEFT"
#             },
#             "layoutAlign": "INHERIT",
#             "layoutGrow": 0.0,
#             "layoutSizingHorizontal": "HUG",
#             "layoutSizingVertical": "HUG",
#             "characters": "22",
#             "characterStyleOverrides": [],
#             "styleOverrideTable": {},
#             "lineTypes": [
#               "NONE"
#             ],
#             "lineIndentations": [
#               0
#             ],
#             "style": {
#               "fontFamily": "Open Sans",
#               "fontPostScriptName": "OpenSans-Bold",
#               "fontStyle": "Bold",
#               "fontWeight": 700,
#               "textAutoResize": "WIDTH_AND_HEIGHT",
#               "fontSize": 128.0,
#               "textAlignHorizontal": "LEFT",
#               "textAlignVertical": "TOP",
#               "letterSpacing": 0.0,
#               "lineHeightPx": 174.3125,
#               "lineHeightPercent": 100.0,
#               "lineHeightUnit": "INTRINSIC_%"
#             },
#             "layoutVersion": 4,
#             "effects": [
#               {
#                 "type": "DROP_SHADOW",
#                 "visible": true,
#                 "color": {
#                   "r": 0.0,
#                   "g": 0.0,
#                   "b": 0.0,
#                   "a": 0.25
#                 },
#                 "blendMode": "NORMAL",
#                 "offset": {
#                   "x": 0.0,
#                   "y": 4.0
#                 },
#                 "radius": 4.0,
#                 "showShadowBehindNode": false
#               }
#             ],
#             "interactions": []
#           },
#           {
#             "id": "31:27",
#             "name": "$api {\"src\":\"https://api.open-meteo.com/v1/forecast?latitude=60.43&longitude=22.22&current_weather=true\",\"path\":\"current_weather_units.temperature\",\"trigger\":\"once\"}",
#             "type": "TEXT",
#             "scrollBehavior": "SCROLLS",
#             "blendMode": "PASS_THROUGH",
#             "fills": [
#               {
#                 "blendMode": "NORMAL",
#                 "type": "SOLID",
#                 "color": {
#                   "r": 0.21960784494876862,
#                   "g": 0.21960784494876862,
#                   "b": 0.250980406999588,
#                   "a": 1.0
#                 }
#               }
#             ],
#             "strokes": [],
#             "strokeWeight": 1.0,
#             "strokeAlign": "OUTSIDE",
#             "absoluteBoundingBox": {
#               "x": 583.0,
#               "y": -412.0,
#               "width": 137.0,
#               "height": 174.0
#             },
#             "absoluteRenderBounds": {
#               "x": 588.0,
#               "y": -367.6875,
#               "width": 126.9375,
#               "height": 93.9375
#             },
#             "constraints": {
#               "vertical": "TOP",
#               "horizontal": "LEFT"
#             },
#             "layoutAlign": "INHERIT",
#             "layoutGrow": 0.0,
#             "layoutSizingHorizontal": "HUG",
#             "layoutSizingVertical": "HUG",
#             "characters": "\u00b0C",
#             "characterStyleOverrides": [],
#             "styleOverrideTable": {},
#             "lineTypes": [
#               "NONE"
#             ],
#             "lineIndentations": [
#               0
#             ],
#             "style": {
#               "fontFamily": "Open Sans",
#               "fontPostScriptName": "OpenSans-Bold",
#               "fontStyle": "Bold",
#               "fontWeight": 700,
#               "textAutoResize": "WIDTH_AND_HEIGHT",
#               "fontSize": 128.0,
#               "textAlignHorizontal": "LEFT",
#               "textAlignVertical": "TOP",
#               "letterSpacing": 0.0,
#               "lineHeightPx": 174.3125,
#               "lineHeightPercent": 100.0,
#               "lineHeightUnit": "INTRINSIC_%"
#             },
#             "layoutVersion": 4,
#             "effects": [],
#             "interactions": []
#           }
#         ],
#         "blendMode": "PASS_THROUGH",
#         "clipsContent": true,
#         "background": [],
#         "fills": [],
#         "strokes": [],
#         "strokeWeight": 1.0,
#         "strokeAlign": "INSIDE",
#         "backgroundColor": {
#           "r": 0.0,
#           "g": 0.0,
#           "b": 0.0,
#           "a": 0.0
#         },
#         "layoutMode": "HORIZONTAL",
#         "itemSpacing": 40.0,
#         "counterAxisAlignItems": "CENTER",
#         "paddingLeft": 10.0,
#         "paddingRight": 10.0,
#         "paddingTop": 10.0,
#         "paddingBottom": 10.0,
#         "layoutWrap": "NO_WRAP",
#         "absoluteBoundingBox": {
#           "x": 386.0,
#           "y": -422.0,
#           "width": 344.0,
#           "height": 194.0
#         },
#         "absoluteRenderBounds": {
#           "x": 386.0,
#           "y": -422.0,
#           "width": 344.0,
#           "height": 194.0
#         },
#         "constraints": {
#           "vertical": "TOP",
#           "horizontal": "LEFT"
#         },
#         "layoutAlign": "INHERIT",
#         "layoutGrow": 0.0,
#         "layoutSizingHorizontal": "HUG",
#         "layoutSizingVertical": "HUG",
#         "effects": [],
#         "interactions": []
#       }
#     ],
#     "blendMode": "PASS_THROUGH",
#     "clipsContent": true,
#     "background": [
#       {
#         "blendMode": "NORMAL",
#         "type": "SOLID",
#         "color": {
#           "r": 1.0,
#           "g": 1.0,
#           "b": 1.0,
#           "a": 1.0
#         }
#       }
#     ],
#     "fills": [
#       {
#         "blendMode": "NORMAL",
#         "type": "SOLID",
#         "color": {
#           "r": 1.0,
#           "g": 1.0,
#           "b": 1.0,
#           "a": 1.0
#         }
#       }
#     ],
#     "strokes": [
#       {
#         "blendMode": "NORMAL",
#         "type": "SOLID",
#         "color": {
#           "r": 0.942307710647583,
#           "g": 0.942307710647583,
#           "b": 0.942307710647583,
#           "a": 1.0
#         }
#       }
#     ],
#     "cornerRadius": 80.0,
#     "cornerSmoothing": 0.0,
#     "strokeWeight": 1.0,
#     "strokeAlign": "INSIDE",
#     "backgroundColor": {
#       "r": 1.0,
#       "g": 1.0,
#       "b": 1.0,
#       "a": 1.0
#     },
#     "layoutMode": "VERTICAL",
#     "itemSpacing": 80.0,
#     "counterAxisAlignItems": "CENTER",
#     "primaryAxisAlignItems": "CENTER",
#     "paddingLeft": 80.0,
#     "paddingRight": 80.0,
#     "paddingTop": 80.0,
#     "paddingBottom": 80.0,
#     "layoutWrap": "NO_WRAP",
#     "absoluteBoundingBox": {
#       "x": 306.0,
#       "y": -674.0,
#       "width": 504.0,
#       "height": 526.0
#     },
#     "absoluteRenderBounds": {
#       "x": 302.0,
#       "y": -674.0,
#       "width": 512.0,
#       "height": 534.0
#     },
#     "constraints": {
#       "vertical": "TOP",
#       "horizontal": "LEFT"
#     },
#     "layoutSizingHorizontal": "HUG",
#     "layoutSizingVertical": "HUG",
#     "effects": [
#       {
#         "type": "DROP_SHADOW",
#         "visible": true,
#         "color": {
#           "r": 0.0,
#           "g": 0.0,
#           "b": 0.0,
#           "a": 0.25
#         },
#         "blendMode": "NORMAL",
#         "offset": {
#           "x": 0.0,
#           "y": 4.0
#         },
#         "radius": 4.0,
#         "showShadowBehindNode": false
#       }
#     ],
#     "interactions": []
#   },
#   {
#     "id": "35:29",
#     "name": "$ui-windspeed-widget",
#     "type": "FRAME",
#     "scrollBehavior": "SCROLLS",
#     "children": [
#       {
#         "id": "35:30",
#         "name": "top",
#         "type": "FRAME",
#         "scrollBehavior": "SCROLLS",
#         "children": [
#           {
#             "id": "35:31",
#             "name": "Windspeed",
#             "type": "TEXT",
#             "scrollBehavior": "SCROLLS",
#             "blendMode": "PASS_THROUGH",
#             "fills": [
#               {
#                 "blendMode": "NORMAL",
#                 "type": "SOLID",
#                 "color": {
#                   "r": 1.0,
#                   "g": 1.0,
#                   "b": 1.0,
#                   "a": 1.0
#                 }
#               }
#             ],
#             "strokes": [],
#             "strokeWeight": 1.0,
#             "strokeAlign": "OUTSIDE",
#             "absoluteBoundingBox": {
#               "x": 1114.0,
#               "y": -570.0,
#               "width": 177.0,
#               "height": 44.0
#             },
#             "absoluteRenderBounds": {
#               "x": 1114.0,
#               "y": -560.3125,
#               "width": 173.734375,
#               "height": 32.0
#             },
#             "constraints": {
#               "vertical": "TOP",
#               "horizontal": "LEFT"
#             },
#             "layoutAlign": "INHERIT",
#             "layoutGrow": 0.0,
#             "layoutSizingHorizontal": "HUG",
#             "layoutSizingVertical": "HUG",
#             "characters": "Windspeed",
#             "characterStyleOverrides": [],
#             "styleOverrideTable": {},
#             "lineTypes": [
#               "NONE"
#             ],
#             "lineIndentations": [
#               0
#             ],
#             "style": {
#               "fontFamily": "Open Sans",
#               "fontPostScriptName": "OpenSans-Bold",
#               "fontStyle": "Bold",
#               "fontWeight": 700,
#               "textAutoResize": "WIDTH_AND_HEIGHT",
#               "fontSize": 32.0,
#               "textAlignHorizontal": "LEFT",
#               "textAlignVertical": "TOP",
#               "letterSpacing": 0.0,
#               "lineHeightPx": 43.578125,
#               "lineHeightPercent": 100.0,
#               "lineHeightUnit": "INTRINSIC_%"
#             },
#             "layoutVersion": 4,
#             "effects": [],
#             "interactions": []
#           }
#         ],
#         "blendMode": "PASS_THROUGH",
#         "clipsContent": true,
#         "background": [
#           {
#             "blendMode": "NORMAL",
#             "type": "SOLID",
#             "color": {
#               "r": 0.21960784494876862,
#               "g": 0.21960784494876862,
#               "b": 0.250980406999588,
#               "a": 1.0
#             }
#           }
#         ],
#         "fills": [
#           {
#             "blendMode": "NORMAL",
#             "type": "SOLID",
#             "color": {
#               "r": 0.21960784494876862,
#               "g": 0.21960784494876862,
#               "b": 0.250980406999588,
#               "a": 1.0
#             }
#           }
#         ],
#         "strokes": [],
#         "cornerRadius": 24.0,
#         "cornerSmoothing": 0.0,
#         "strokeWeight": 1.0,
#         "strokeAlign": "INSIDE",
#         "backgroundColor": {
#           "r": 0.21960784494876862,
#           "g": 0.21960784494876862,
#           "b": 0.250980406999588,
#           "a": 1.0
#         },
#         "layoutMode": "HORIZONTAL",
#         "itemSpacing": 10.0,
#         "primaryAxisSizingMode": "FIXED",
#         "counterAxisAlignItems": "MAX",
#         "paddingLeft": 24.0,
#         "paddingRight": 24.0,
#         "paddingTop": 24.0,
#         "paddingBottom": 24.0,
#         "layoutWrap": "NO_WRAP",
#         "absoluteBoundingBox": {
#           "x": 1090.0,
#           "y": -594.0,
#           "width": 673.0,
#           "height": 92.0
#         },
#         "absoluteRenderBounds": {
#           "x": 1086.0,
#           "y": -594.0,
#           "width": 681.0,
#           "height": 100.0
#         },
#         "constraints": {
#           "vertical": "TOP",
#           "horizontal": "LEFT"
#         },
#         "layoutAlign": "STRETCH",
#         "layoutGrow": 0.0,
#         "layoutSizingHorizontal": "FILL",
#         "layoutSizingVertical": "HUG",
#         "effects": [
#           {
#             "type": "DROP_SHADOW",
#             "visible": true,
#             "color": {
#               "r": 0.0,
#               "g": 0.0,
#               "b": 0.0,
#               "a": 0.25
#             },
#             "blendMode": "NORMAL",
#             "offset": {
#               "x": 0.0,
#               "y": 4.0
#             },
#             "radius": 4.0,
#             "showShadowBehindNode": false
#           }
#         ],
#         "interactions": []
#       },
#       {
#         "id": "35:32",
#         "name": "bottom",
#         "type": "FRAME",
#         "scrollBehavior": "SCROLLS",
#         "children": [
#           {
#             "id": "35:33",
#             "name": "$api {\"src\":\"https://api.open-meteo.com/v1/forecast?latitude=60.43&longitude=22.22&current_weather=true\",\"path\":\"current_weather.windspeed\",\"trigger\":\"once\"}",
#             "type": "TEXT",
#             "scrollBehavior": "SCROLLS",
#             "blendMode": "PASS_THROUGH",
#             "fills": [
#               {
#                 "blendMode": "NORMAL",
#                 "type": "SOLID",
#                 "color": {
#                   "r": 0.21960784494876862,
#                   "g": 0.21960784494876862,
#                   "b": 0.250980406999588,
#                   "a": 1.0
#                 }
#               }
#             ],
#             "strokes": [],
#             "strokeWeight": 1.0,
#             "strokeAlign": "OUTSIDE",
#             "absoluteBoundingBox": {
#               "x": 1100.0,
#               "y": -412.0,
#               "width": 350.0,
#               "height": 174.0
#             },
#             "absoluteRenderBounds": {
#               "x": 1096.0,
#               "y": -372.25,
#               "width": 351.625,
#               "height": 106.5
#             },
#             "constraints": {
#               "vertical": "TOP",
#               "horizontal": "LEFT"
#             },
#             "layoutAlign": "INHERIT",
#             "layoutGrow": 0.0,
#             "layoutSizingHorizontal": "HUG",
#             "layoutSizingVertical": "HUG",
#             "characters": "value",
#             "characterStyleOverrides": [],
#             "styleOverrideTable": {},
#             "lineTypes": [
#               "NONE"
#             ],
#             "lineIndentations": [
#               0
#             ],
#             "style": {
#               "fontFamily": "Open Sans",
#               "fontPostScriptName": "OpenSans-Bold",
#               "fontStyle": "Bold",
#               "fontWeight": 700,
#               "textAutoResize": "WIDTH_AND_HEIGHT",
#               "fontSize": 128.0,
#               "textAlignHorizontal": "LEFT",
#               "textAlignVertical": "TOP",
#               "letterSpacing": 0.0,
#               "lineHeightPx": 174.3125,
#               "lineHeightPercent": 100.0,
#               "lineHeightUnit": "INTRINSIC_%"
#             },
#             "layoutVersion": 4,
#             "effects": [
#               {
#                 "type": "DROP_SHADOW",
#                 "visible": true,
#                 "color": {
#                   "r": 0.0,
#                   "g": 0.0,
#                   "b": 0.0,
#                   "a": 0.25
#                 },
#                 "blendMode": "NORMAL",
#                 "offset": {
#                   "x": 0.0,
#                   "y": 4.0
#                 },
#                 "radius": 4.0,
#                 "showShadowBehindNode": false
#               }
#             ],
#             "interactions": []
#           },
#           {
#             "id": "35:34",
#             "name": "$api {\"src\":\"https://api.open-meteo.com/v1/forecast?latitude=60.43&longitude=22.22&current_weather=true\",\"path\":\"current_weather_units.windspeed\",\"trigger\":\"once\"}",
#             "type": "TEXT",
#             "scrollBehavior": "SCROLLS",
#             "blendMode": "PASS_THROUGH",
#             "fills": [
#               {
#                 "blendMode": "NORMAL",
#                 "type": "SOLID",
#                 "color": {
#                   "r": 0.21960784494876862,
#                   "g": 0.21960784494876862,
#                   "b": 0.250980406999588,
#                   "a": 1.0
#                 }
#               }
#             ],
#             "strokes": [],
#             "strokeWeight": 1.0,
#             "strokeAlign": "OUTSIDE",
#             "absoluteBoundingBox": {
#               "x": 1490.0,
#               "y": -412.0,
#               "width": 263.0,
#               "height": 174.0
#             },
#             "absoluteRenderBounds": {
#               "x": 1499.625,
#               "y": -372.25,
#               "width": 249.1875,
#               "height": 98.5
#             },
#             "constraints": {
#               "vertical": "TOP",
#               "horizontal": "LEFT"
#             },
#             "layoutAlign": "INHERIT",
#             "layoutGrow": 0.0,
#             "layoutSizingHorizontal": "HUG",
#             "layoutSizingVertical": "HUG",
#             "characters": "unit",
#             "characterStyleOverrides": [],
#             "styleOverrideTable": {},
#             "lineTypes": [
#               "NONE"
#             ],
#             "lineIndentations": [
#               0
#             ],
#             "style": {
#               "fontFamily": "Open Sans",
#               "fontPostScriptName": "OpenSans-Bold",
#               "fontStyle": "Bold",
#               "fontWeight": 700,
#               "textAutoResize": "WIDTH_AND_HEIGHT",
#               "fontSize": 128.0,
#               "textAlignHorizontal": "LEFT",
#               "textAlignVertical": "TOP",
#               "letterSpacing": 0.0,
#               "lineHeightPx": 174.3125,
#               "lineHeightPercent": 100.0,
#               "lineHeightUnit": "INTRINSIC_%"
#             },
#             "layoutVersion": 4,
#             "effects": [],
#             "interactions": []
#           }
#         ],
#         "blendMode": "PASS_THROUGH",
#         "clipsContent": true,
#         "background": [],
#         "fills": [],
#         "strokes": [],
#         "strokeWeight": 1.0,
#         "strokeAlign": "INSIDE",
#         "backgroundColor": {
#           "r": 0.0,
#           "g": 0.0,
#           "b": 0.0,
#           "a": 0.0
#         },
#         "layoutMode": "HORIZONTAL",
#         "itemSpacing": 40.0,
#         "counterAxisAlignItems": "CENTER",
#         "paddingLeft": 10.0,
#         "paddingRight": 10.0,
#         "paddingTop": 10.0,
#         "paddingBottom": 10.0,
#         "layoutWrap": "NO_WRAP",
#         "absoluteBoundingBox": {
#           "x": 1090.0,
#           "y": -422.0,
#           "width": 673.0,
#           "height": 194.0
#         },
#         "absoluteRenderBounds": {
#           "x": 1090.0,
#           "y": -422.0,
#           "width": 673.0,
#           "height": 194.0
#         },
#         "constraints": {
#           "vertical": "TOP",
#           "horizontal": "LEFT"
#         },
#         "layoutAlign": "INHERIT",
#         "layoutGrow": 0.0,
#         "layoutSizingHorizontal": "HUG",
#         "layoutSizingVertical": "HUG",
#         "effects": [],
#         "interactions": []
#       }
#     ],
#     "blendMode": "PASS_THROUGH",
#     "clipsContent": true,
#     "background": [
#       {
#         "blendMode": "NORMAL",
#         "type": "SOLID",
#         "color": {
#           "r": 1.0,
#           "g": 1.0,
#           "b": 1.0,
#           "a": 1.0
#         }
#       }
#     ],
#     "fills": [
#       {
#         "blendMode": "NORMAL",
#         "type": "SOLID",
#         "color": {
#           "r": 1.0,
#           "g": 1.0,
#           "b": 1.0,
#           "a": 1.0
#         }
#       }
#     ],
#     "strokes": [
#       {
#         "blendMode": "NORMAL",
#         "type": "SOLID",
#         "color": {
#           "r": 0.942307710647583,
#           "g": 0.942307710647583,
#           "b": 0.942307710647583,
#           "a": 1.0
#         }
#       }
#     ],
#     "cornerRadius": 80.0,
#     "cornerSmoothing": 0.0,
#     "strokeWeight": 1.0,
#     "strokeAlign": "INSIDE",
#     "backgroundColor": {
#       "r": 1.0,
#       "g": 1.0,
#       "b": 1.0,
#       "a": 1.0
#     },
#     "layoutMode": "VERTICAL",
#     "itemSpacing": 80.0,
#     "counterAxisAlignItems": "CENTER",
#     "primaryAxisAlignItems": "CENTER",
#     "paddingLeft": 80.0,
#     "paddingRight": 80.0,
#     "paddingTop": 80.0,
#     "paddingBottom": 80.0,
#     "layoutWrap": "NO_WRAP",
#     "absoluteBoundingBox": {
#       "x": 1010.0,
#       "y": -674.0,
#       "width": 833.0,
#       "height": 526.0
#     },
#     "absoluteRenderBounds": {
#       "x": 1006.0,
#       "y": -674.0,
#       "width": 841.0,
#       "height": 534.0
#     },
#     "constraints": {
#       "vertical": "TOP",
#       "horizontal": "LEFT"
#     },
#     "layoutSizingHorizontal": "HUG",
#     "layoutSizingVertical": "HUG",
#     "effects": [
#       {
#         "type": "DROP_SHADOW",
#         "visible": true,
#         "color": {
#           "r": 0.0,
#           "g": 0.0,
#           "b": 0.0,
#           "a": 0.25
#         },
#         "blendMode": "NORMAL",
#         "offset": {
#           "x": 0.0,
#           "y": 4.0
#         },
#         "radius": 4.0,
#         "showShadowBehindNode": false
#       }
#     ],
#     "interactions": []
#   }
# ]

# %%
if __name__ == "__main__":
    # 1) load your saved Figma JSON (from get_project_json)
    with open("figma_file.json", encoding="utf-8") as f:
        figma_data = json.load(f)

    # 2) find the document root
    document = figma_data["document"]

    # 3) locate all UI frames (e.g. names starting with "$ui")
    def find_ui_frames(node):
        out = []
        if node.get("type") == "FRAME" and node.get("name", "").startswith("$ui"):
            out.append(node)
        for c in node.get("children", []):
            out += find_ui_frames(c)
        return out

    ui_frames = find_ui_frames(document)

    # 4) convert the first one into a fasthtml tree
    if ui_frames:
        tree = figma_node_to_fasthtml(ui_frames[0])
        # 5) render to HTML
        html_str = tree.render()
        print(html_str)
